# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 下載檔案

# %%
import requests

r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"12838546016","type":"CreateEvent","actor":{"id":43152844,"login":"hail-ci-test-1","display_login":"hail-ci-test-1","gravatar_id":"","url":"https://api.github.com/users/hail-ci-test-1","avatar_url":"https://avatars.githubusercontent.com/u/43152844?"},"repo":{"id":277883183,"name":"hail-ci-test/ci-test-yss7unbt828r","url":"https://api.github.com/repos/hail-ci-test/ci-test-yss7unbt828r"},"payload":{"ref":null,"ref_type":"repository","master_branch":"master","description":null,"pusher_type":"user"},"public":true,"created_at":"2020-07-07T17:39:53Z","org":{"id":43152710,"login":"hail-ci-test","gravatar_id":"","url":"https://api.github.com/orgs/hail-ci-test","avatar_url":"https://avatars.githubusercontent.com/u/43152710?"}},{"id":"12838546001","type":"PushEvent","actor":{"id":26708852,"login":"stongcoder","display_login":"stongcoder","gravatar_id":"","url":"https://api.github.com/users/stongcoder","avatar_url":"https://avatars.githubusercontent.com/u/26708852?"},"repo":{"id":277824847,"name":"stongcoder/stongcoder.github.io","url":"https://api.github.com/repos/stongcoder/stongcoder.github.io"},"payload":{"push_id":5339241267,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"ea63d5738fbea8fe47788aab2585fb00f44d8af7","before":"ba234bcca3a299ff889571e07ae935aaddd37bc5","commits":[{"sha":"ea63d5738fbea8fe47788aab2585fb00f44d8af7","author":{"email":"17729097884@163.com","name":"RenYuhang"},"message":"test","distinct":true,"url":"https://api.github.com/repos/stongcoder/stongcoder.github.io/commits/ea63d5738fbea8fe47788aab2585fb00f44d8af7"}]},"public":true,"created_at":"2020-07-07T17:39:53Z"},{"id":"12838545999","type":"CreateEvent","actor":{"id":45714243,"login":"mark-j-chilvers","display_login":"mark-j-chilvers","gravatar_id":"","url":"https://api.github.com/users/mark-j-chilvers","avatar_url":"https://avatars.githubusercontent.com/u/45714243?"},"repo":{"id":277883184,"name":"mark-j-chilvers/anthos-hydrated-config","url":"https://api.github.com/repos/mark-j-chilvers/anthos-hydrated-config"},"payload":{"ref":null,"ref_type":"repository","master_branch":"master","description":null,"pusher_type":"user"},"public":true,"created_at":"2020-07-07T17:39:53Z"},{"id":"12838545993","type":"PushEvent","actor":{"id":67932427,"login":"courtneyyargo","display_login":"courtneyyargo","gravatar_id":"","url":"https://api.github.com/users/courtneyyargo","avatar_url":"https://avatars.githubusercontent.com/u/67932427?"},"repo":{"id":277669460,"name":"courtneyyargo/ruby-variable-assignment-onl01-seng-pt-070620","url":"https://api.github.com/repos/courtneyyargo/ruby-variable-assignment-onl01-seng-pt-070620"},"payload":{"push_id":5339241264,"size":1,"distinct_size":1,"ref":"refs/heads/wip","head":"77f0b03278280b4d08e89455f2f3d0a52275ce37","before":"04d9e3fa26af92649deb77b83af32a6b6e6346d1","commits":[{"sha":"77f0b03278280b4d08e89455f2f3d0a52275ce37","author":{"email":"courtneyyargo@gmail.com","name":"Courtney Yargo"},"message":"Automatically backed up by Learn","distinct":true,"url":"https://api.github.com/repos/courtneyyargo/ruby-variable-assignment-onl01-seng-pt-070620/commits/77f0b03278280b4d08e89455f2f3d0a52275ce37"}]},"public":true,"created_at":"2020-07-07T17:39:53Z"},{"id":"12838545980","type":"PushEvent","actor":{"id":43336419,"login":"paroxid","display_login":"paroxid","gravatar_id":"","url":"https://api.github.com/users/paroxid","avatar_url":"https://avatars.githubusercontent.com/u/43336419?"},"repo":{"id":276917612,"name":"paroxid/fi_site","url":"https://api.github.com/repos/paroxid/fi_site"},"payload":{"push_id":5339241260,"size":2,"distinct_size":2,"ref":"refs/heads/master","head":"bff2a3d4c571748a68289be54e57c5fca38e3db1","before":"194a45944bc403d4de02d8c0b10e9647be19ec15","commits":[{"sha":"8f0e1058fa9dc3171bb0421aee7ce8df8648c61b","author":{"email":"43336419+paroxid@users.noreply.github.com","name":"paroxid"},"message":"1.1","distinct":true,"url":"https://api.github.com/repos/paroxid/fi_site/commits/8f0e1058fa9dc3171bb0421aee7ce8 ...

# %%
import json

json.loads(r.text)
# Out:
# [{'id': '12838546016',
#   'type': 'CreateEvent',
#   'actor': {'id': 43152844,
#    'login': 'hail-ci-test-1',
#    'display_login': 'hail-ci-test-1',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/hail-ci-test-1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/43152844?'},
#   'repo': {'id': 277883183,
#    'name': 'hail-ci-test/ci-test-yss7unbt828r',
#    'url': 'https://api.github.com/repos/hail-ci-test/ci-test-yss7unbt828r'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-07-07T17:39:53Z',
#   'org': {'id': 43152710,
#    'login': 'hail-ci-test',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/hail-ci-test',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/43152710?'}},
#  {'id': '12838546001',
#   'type': 'PushEvent',
#   'actor': {'id': 26708852,
#    'login': 'stongcoder',
#    'display_login': 'stongcoder',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/stongcoder',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26708852?'},
#   'repo': {'id': 277824847,
#    'name': 'stongcoder/stongcoder.github.io',
#    'url': 'https://api.github.com/repos/stongcoder/stongcoder.github.io'},
#   'payload': {'push_id': 5339241267,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'ea63d5738fbea8fe47788aab2585fb00f44d8af7',
#    'before': 'ba234bcca3a299ff889571e07ae935aaddd37bc5',
#    'commits': [{'sha': 'ea63d5738fbea8fe47788aab2585fb00f44d8af7',
#      'author': {'email': '17729097884@163.com', 'name': 'RenYuhang'},
#      'message': 'test',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/stongcoder/stongcoder.github.io/commits/ea63d5738fbea8fe47788aab2585fb00f44d8af7'}]},
#   'public': True,
#   'created_at': '2020-07-07T17:39:53Z'},
#  {'id': '12838545999',
#   'type': 'CreateEvent',
#   'actor': {'id': 45714243,
#    'login': 'mark-j-chilvers',
#    'display_login': 'mark-j-chilvers',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mark-j-chilvers',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/45714243?'},
#   'repo': {'id': 277883184,
#    'name': 'mark-j-chilvers/anthos-hydrated-config',
#    'url': 'https://api.github.com/repos/mark-j-chilvers/anthos-hydrated-config'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-07-07T17:39:53Z'},
#  {'id': '12838545993',
#   'type': 'PushEvent',
#   'actor': {'id': 67932427,
#    'login': 'courtneyyargo',
#    'display_login': 'courtneyyargo',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/courtneyyargo',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/67932427?'},
#   'repo': {'id': 277669460,
#    'name': 'courtneyyargo/ruby-variable-assignment-onl01-seng-pt-070620',
#    'url': 'https://api.github.com/repos/courtneyyargo/ruby-variable-assignment-onl01-seng-pt-070620'},
#   'payload': {'push_id': 5339241264,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/wip',
#    'head': '77f0b03278280b4d08e89455f2f3d0a52275ce37',
#    'before': '04d9e3fa26af92649deb77b83af32a6b6e6346d1',
#    'commits': [{'sha': '77f0b03278280b4d08e89455f2f3d0a52275ce37',
#      'author': {'email': 'courtneyyargo@gmail.com', 'name': 'Courtney Yargo'},
#      'message': 'Automatically backed up by Learn',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/courtneyyargo/ruby-variable-assignment-onl01-seng-pt-070620/commits/77f0b03278280b4d08e89455f2f3d0a52275ce37'}]},
#   'public': True,
#   'created_at': '2020-07-07T17:39:53Z'},
#  {'id': '12838545980',
#   'type': 'PushEvent',
#   'actor': {'id': 43336419,
#    'login': 'paroxid',
#    'display_login': 'paroxid',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/paroxid',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/43336419?'},
#   'repo': {'id': 276917612,
#    'name': 'paroxid/fi_site',
#    'url': 'https://api.github.com/repos/paroxid/fi_site'},
#   'payload': {'push_id': 5339241260,
#    'size': 2,
#    'distinct_size': 2,
#    'ref': 'refs/heads/master',
#    'head': 'bff2a3d4c571748a68289be54e57c5fca38e3db1',
#    'before': '194a45944bc403d4de02d8c0b10e9647be19ec15',
#    'commits': [{'sha': '8f0e1058fa9dc3171bb0421aee7ce8df8648c61b',
#      'author': {'email': '43336419+paroxid@users.noreply.github.com',
#       'name': 'paroxid'},
#      'message': '1.1',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/paroxid/fi_site/commits/8f0e1058fa9dc3171bb0421aee7ce8df8648c61b'},
#     {'sha': 'bff2a3d4c571748a68289be54e57c5fca38e3db1',
#      'author': {'email': '43336419+paroxid@users.noreply.github.com',
#       'name': 'paroxid'},
#      'message': "Merge branch 'master' of https://github.com/paroxid/fi_site",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/paroxid/fi_site/commits/bff2a3d4c571748a68289be54e57c5fca38e3db1'}]},
#   'public': True,
#   'created_at': '2020-07-07T17:39:53Z'},
#  {'id': '12838545974',
#   'type': 'PushEvent',
#   'actor': {'id': 25855006,
#    'login': 'quetric',
#    'display_login': 'quetric',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/quetric',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/25855006?'},
#   'repo': {'id': 258732901,
#    'name': 'quetric/finn',
#    'url': 'https://api.github.com/repos/quetric/finn'},
#   'payload': {'push_id': 5339241255,
#    'size': 12,
#    'distinct_size': 8,
#    'ref': 'refs/heads/vitis',
#    'head': '2e17743d808c4904be33a28fe6370cdf3aaf9679',
#    'before': 'c0de0e92cd6a27bff1a8cc869ccee70b8b24b177',
#    'commits': [{'sha': '48205178187474d1981b10fb9588c1a80a032424',
#      'author': {'email': 'lucianp@xilinx.com', 'name': 'Lucian Petrica'},
#      'message': 'Added explicit naming of HDL interfaces, for use during ip stitching',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/quetric/finn/commits/48205178187474d1981b10fb9588c1a80a032424'},
#     {'sha': '472b3ae821ab24fbb5167a1514d58776b9cb86e0',
#      'author': {'email': 'lucianp@xilinx.com', 'name': 'Lucian Petrica'},
#      'message': 'Updated stitching transform; updated other transforms as a result of changing input/output_names to s_axis_* and m_axis_*',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/quetric/finn/commits/472b3ae821ab24fbb5167a1514d58776b9cb86e0'},
#     {'sha': '57cbc9206fc0a2a4b75853f875671cda21f1184d',
#      'author': {'email': 'lucianp@xilinx.com', 'name': 'Lucian Petrica'},
#      'message': "Merge branch 'feature_stitch_nonlinear' into vitis",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/quetric/finn/commits/57cbc9206fc0a2a4b75853f875671cda21f1184d'},
#     {'sha': 'b04acc4f6516d65b001f78d1795d22edb1fa70f8',
#      'author': {'email': 'maltanar@gmail.com', 'name': 'Yaman Umuroglu'},
#      'message': '[Docker] install pytest-parallel',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/quetric/finn/commits/b04acc4f6516d65b001f78d1795d22edb1fa70f8'},
#     {'sha': '98d815514ab394443494dc37d8323a6f03a6fbd8',
#      'author': {'email': 'lucianp@xilinx.com', 'name': 'Lucian Petrica'},
#      'message': "Merge branch 'feature_hdl_intf_names' into vitis",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/quetric/finn/commits/98d815514ab394443494dc37d8323a6f03a6fbd8'},
#     {'sha': '215729ee1eeb1139ec008e4c9c9b2f55bffed87f',
#      'author': {'email': 'lucianp@xilinx.com', 'name': 'Lucian Petrica'},
#      'message': 'Updated driver generation transform and template',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/quetric/finn/commits/215729ee1eeb1139ec008e4c9c9b2f55bffed87f'},
#     {'sha': '6eaec376e4a23bf70bc54d2c21ae5393fc0b4879',
#      'author': {'email': 'lucianp@xilinx.com', 'name': 'Lucian Petrica'},
#      'message': "Merge remote-tracking branch 'upstream/dev' into vitis",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/quetric/finn/commits/6eaec376e4a23bf70bc54d2c21ae5393fc0b4879'},
#     {'sha': 'b1357d8dc737541ecb08ca572808588232a32870',
#      'author': {'email': 'lucianp@xilinx.com', 'name': 'Lucian Petrica'},
#      'message': "Merge branch 'feature_pynq_driver_vitis' into vitis",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/quetric/finn/commits/b1357d8dc737541ecb08ca572808588232a32870'},
#     {'sha': '740af0c58ee0a6a6b2e001518dc80e856b77226b',
#      'author': {'email': 'lucianp@xilinx.com', 'name': 'Lucian Petrica'},
#      'message': 'Skip non-existant connections',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/quetric/finn/commits/740af0c58ee0a6a6b2e001518dc80e856b77226b'},
#     {'sha': '1a8d043962d58424063c03085515e46657c313c5',
#      'author': {'email': 'lucianp@xilinx.com', 'name': 'Lucian Petrica'},
#      'message': 'Fixed casting clk_ns',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/quetric/finn/commits/1a8d043962d58424063c03085515e46657c313c5'},
#     {'sha': 'e614a1475792b06af7bc0497c587471c7adce8ee',
#      'author': {'email': 'lucianp@xilinx.com', 'name': 'Lucian Petrica'},
#      'message': 'Fix for partitions which contain just a single IODMA',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/quetric/finn/commits/e614a1475792b06af7bc0497c587471c7adce8ee'},
#     {'sha': '2e17743d808c4904be33a28fe6370cdf3aaf9679',
#      'author': {'email': 'lucianp@xilinx.com', 'name': 'Lucian Petrica'},
#      'message': 'Added transform for building design with custom (non-Pynq) Zynq shell',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/quetric/finn/commits/2e17743d808c4904be33a28fe6370cdf3aaf9679'}]},
#   'public': True,
#   'created_at': '2020-07-07T17:39:53Z'},
#  {'id': '12838545990',
#   'type': 'CreateEvent',
#   'actor': {'id': 64177680,
#    'login': '10hley-syl20',
#    'display_login': '10hley-syl20',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/10hley-syl20',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/64177680?'},
#   'repo': {'id': 277883181,
#    'name': '10hley-syl20/colorgame',
#    'url': 'https://api.github.com/repos/10hley-syl20/colorgame'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-07-07T17:39:53Z'},
#  {'id': '12838545984',
#   'type': 'CreateEvent',
#   'actor': {'id': 40853054,
#    'login': 'omartarek206',
#    'display_login': 'omartarek206',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/omartarek206',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/40853054?'},
#   'repo': {'id': 277883182,
#    'name': 'omartarek206/cs50w',
#    'url': 'https://api.github.com/repos/omartarek206/cs50w'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-07-07T17:39:53Z'},
#  {'id': '12838545987',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 98381,
#    'login': 'FunnyMan3595',
#    'display_login': 'FunnyMan3595',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/FunnyMan3595',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/98381?'},
#   'repo': {'id': 5973855,
#    'name': 'CleverRaven/Cataclysm-DDA',
#    'url': 'https://api.github.com/repos/CleverRaven/Cataclysm-DDA'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/CleverRaven/Cataclysm-DDA/issues/41927',
#     'repository_url': 'https://api.github.com/repos/CleverRaven/Cataclysm-DDA',
#     'labels_url': 'https://api.github.com/repos/CleverRaven/Cataclysm-DDA/issues/41927/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/CleverRaven/Cataclysm-DDA/issues/41927/comments',
#     'events_url': 'https://api.github.com/repos/CleverRaven/Cataclysm-DDA/issues/41927/events',
#     'html_url': 'https://github.com/CleverRaven/Cataclysm-DDA/issues/41927',
#     'id': 652501000,
#     'node_id': 'MDU6SXNzdWU2NTI1MDEwMDA=',
#     'number': 41927,
#     'title': 'R&D',
#     'user': {'login': 'FunnyMan3595',
#      'id': 98381,
#      'node_id': 'MDQ6VXNlcjk4Mzgx',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/98381?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/FunnyMan3595',
#      'html_url': 'https://github.com/FunnyMan3595',
#      'followers_url': 'https://api.github.com/users/FunnyMan3595/followers',
#      'following_url': 'https://api.github.com/users/FunnyMan3595/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/FunnyMan3595/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/FunnyMan3595/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/FunnyMan3595/subscriptions',
#      'organizations_url': 'https://api.github.com/users/FunnyMan3595/orgs',
#      'repos_url': 'https://api.github.com/users/FunnyMan3595/repos',
#      'events_url': 'https://api.github.com/users/FunnyMan3595/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/FunnyMan3595/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2020-07-07T17:38:57Z',
#     'updated_at': '2020-07-07T17:39:53Z',
#     'closed_at': None,
#     'author_association': 'CONTRIBUTOR',
#     'active_lock_reason': None,
#     'body': '# Is your feature request related to a problem? Please describe.\r\nMany recipes are currently unavailable without a matching book, even though it would be feasible to experiment and figure out a way to make them, especially if a character has a vague idea of how that might work.  Glassblowing, for instance, would be difficult (but not impossible) to figure out without a reference book, just by knowing that a process called "glassblowing" exists.\r\n\r\n# Describe the solution you\'d like\r\nCreate a new R&D system, parallel to the existing crafting system, that allows the player to experiment and discover new recipes at the cost of materials and time.  The end result of R&D would be a single prototype item, and would also unlock the standard recipe (if any).  High-end recipes should be locked behind a mod (if available at all).\r\n\r\n# Describe alternatives you\'ve considered\r\nA simpler system that just lets you try an unknown recipe with a failure chance would also solve the basic problem, but seems less interesting and less open to expansion.\r\n\r\n# Additional context\r\nn/a\r\n'},
#    'comment': {'url': 'https://api.github.com/repos/CleverRaven/Cataclysm-DDA/issues/comments/655018349',
#     'html_url': 'https://github.com/CleverRaven/Cataclysm-DDA/issues/41927#issuecomment-655018349',
#     'issue_url': 'https://api.github.com/repos/CleverRaven/Cataclysm-DDA/issues/41927',
#     'id': 655018349,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDY1NTAxODM0OQ==',
#     'user': {'login': 'FunnyMan3595',
#      'id': 98381,
#      'node_id': 'MDQ6VXNlcjk4Mzgx',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/98381?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/FunnyMan3595',
#      'html_url': 'https://github.com/FunnyMan3595',
#      'followers_url': 'https://api.github.com/users/FunnyMan3595/followers',
#      'following_url': 'https://api.github.com/users/FunnyMan3595/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/FunnyMan3595/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/FunnyMan3595/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/FunnyMan3595/subscriptions',
#      'organizations_url': 'https://api.github.com/users/FunnyMan3595/orgs',
#      'repos_url': 'https://api.github.com/users/FunnyMan3595/repos',
#      'events_url': 'https://api.github.com/users/FunnyMan3595/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/FunnyMan3595/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2020-07-07T17:39:53Z',
#     'updated_at': '2020-07-07T17:39:53Z',
#     'author_association': 'CONTRIBUTOR',
#     'body': "(I'm planning to implement this in the near future, once I've fleshed it out a bit)"}},
#   'public': True,
#   'created_at': '2020-07-07T17:39:53Z',
#   'org': {'id': 4367009,
#    'login': 'CleverRaven',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/CleverRaven',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/4367009?'}},
#  {'id': '12838545959',
#   'type': 'PushEvent',
#   'actor': {'id': 64931408,
#    'login': 'estein1988',
#    'display_login': 'estein1988',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/estein1988',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/64931408?'},
#   'repo': {'id': 277879163,
#    'name': 'estein1988/programming-univbasics-4-building-nested-hashes-den01-seng-ft-080320',
#    'url': 'https://api.github.com/repos/estein1988/programming-univbasics-4-building-nested-hashes-den01-seng-ft-080320'},
#   'payload': {'push_id': 5339241246,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/wip',
#    'head': '4c2bc03760f6881cfc2656da7734f5b6739d9955',
#    'before': 'ffedeaafb93aea47e90fd0ae93c9b7bc32b32af1',
#    'commits': [{'sha': '4c2bc03760f6881cfc2656da7734f5b6739d9955',
#      'author': {'email': 'estein1988@gmail.com', 'name': 'Elliott Stein'},
#      'message': 'Automatically backed up by Learn',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/estein1988/programming-univbasics-4-building-nested-hashes-den01-seng-ft-080320/commits/4c2bc03760f6881cfc2656da7734f5b6739d9955'}]},
#   'public': True,
#   'created_at': '2020-07-07T17:39:53Z'},
#  {'id': '12838545970',
#   'type': 'PushEvent',
#   'actor': {'id': 1379875,
#    'login': 'dlaehnemann',
#    'display_login': 'dlaehnemann',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dlaehnemann',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1379875?'},
#   'repo': {'id': 29821195,
#    'name': 'rust-bio/rust-bio',
#    'url': 'https://api.github.com/repos/rust-bio/rust-bio'},
#   'payload': {'push_id': 5339241258,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/cdf-improve-docs',
#    'head': '84ef77abd1674c008ced4397f45dddb8a62745e1',
#    'before': '22d185eba5de8fc2f3615cf0a177274b86ac1670',
#    'commits': [{'sha': '84ef77abd1674c008ced4397f45dddb8a62745e1',
#      'author': {'email': 'david.laehnemann@hhu.de',
#       'name': 'David Laehnemann'},
#      'message': 'Moved doctest to module level documentation. Not yet finished with examples for all.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/rust-bio/rust-bio/commits/84ef77abd1674c008ced4397f45dddb8a62745e1'}]},
#   'public': True,
#   'created_at': '2020-07-07T17:39:53Z',
#   'org': {'id': 13785584,
#    'login': 'rust-bio',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/rust-bio',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/13785584?'}},
#  {'id': '12838545971',
#   'type': 'CreateEvent',
#   'actor': {'id': 66789135,
#    'login': 'keldykins',
#    'display_login': 'keldykins',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/keldykins',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/66789135?'},
#   'repo': {'id': 277883175,
#    'name': 'keldykins/hw2portfolio',
#    'url': 'https://api.github.com/repos/keldykins/hw2portfolio'},
#   'payload': {'ref': 'master',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'responsive portfolio',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-07-07T17:39:53Z'},
#  {'id': '12838545951',
#   'type': 'PushEvent',
#   'actor': {'id': 61248571,
#    'login': 'lballesterosm',
#    'display_login': 'lballesterosm',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lballesterosm',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61248571?'},
#   'repo': {'id': 275005734,
#    'name': 'lballesterosm/ansible_t_repo',
#    'url': 'https://api.github.com/repos/lballesterosm/ansible_t_repo'},
#   'payload': {'push_id': 5339241247,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '29dab93b73a5f8612a1d3b8566c92076033926e0',
#    'before': '3abbadd25819501ec159837c887adaa0c1fdc84b',
#    'commits': [{'sha': '29dab93b73a5f8612a1d3b8566c92076033926e0',
#      'author': {'email': 'leonardo.ballesteros@ibm.com', 'name': 'unknown'},
#      'message': 'Version probada en testing',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/lballesterosm/ansible_t_repo/commits/29dab93b73a5f8612a1d3b8566c92076033926e0'}]},
#   'public': True,
#   'created_at': '2020-07-07T17:39:53Z'},
#  {'id': '12838545966',
#   'type': 'WatchEvent',
#   'actor': {'id': 40660121,
#    'login': 'colinaaa',
#    'display_login': 'colinaaa',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/colinaaa',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/40660121?'},
#   'repo': {'id': 165658820,
#    'name': 'donavon/use-dark-mode',
#    'url': 'https://api.github.com/repos/donavon/use-dark-mode'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2020-07-07T17:39:53Z'},
#  {'id': '12838545964',
#   'type': 'CreateEvent',
#   'actor': {'id': 37123902,
#    'login': 'atlantisbot',
#    'display_login': 'atlantisbot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/atlantisbot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/37123902?'},
#   'repo': {'id': 120520862,
#    'name': 'runatlantis/atlantis-tests',
#    'url': 'https://api.github.com/repos/runatlantis/atlantis-tests'},
#   'payload': {'ref': 'standalone-20200707173948',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'A set of terraform projects that atlantis e2e tests run on.',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-07-07T17:39:53Z',
#   'org': {'id': 32311288,
#    'login': 'runatlantis',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/runatlantis',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/32311288?'}},
#  {'id': '12838545963',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 37123902,
#    'login': 'atlantisbot',
#    'display_login': 'atlantisbot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/atlantisbot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/37123902?'},
#   'repo': {'id': 120520862,
#    'name': 'runatlantis/atlantis-tests',
#    'url': 'https://api.github.com/repos/runatlantis/atlantis-tests'},
#   'payload': {'action': 'opened',
#    'number': 1751,
#    'pull_request': {'url': 'https://api.github.com/repos/runatlantis/atlantis-tests/pulls/1751',
#     'id': 445557522,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0NDQ1NTU3NTIy',
#     'html_url': 'https://github.com/runatlantis/atlantis-tests/pull/1751',
#     'diff_url': 'https://github.com/runatlantis/atlantis-tests/pull/1751.diff',
#     'patch_url': 'https://github.com/runatlantis/atlantis-tests/pull/1751.patch',
#     'issue_url': 'https://api.github.com/repos/runatlantis/atlantis-tests/issues/1751',
#     'number': 1751,
#     'state': 'open',
#     'locked': False,
#     'title': 'This is a test pull request for atlantis e2e test for standalone project type',
#     'user': {'login': 'atlantisbot',
#      'id': 37123902,
#      'node_id': 'MDQ6VXNlcjM3MTIzOTAy',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/37123902?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/atlantisbot',
#      'html_url': 'https://github.com/atlantisbot',
#      'followers_url': 'https://api.github.com/users/atlantisbot/followers',
#      'following_url': 'https://api.github.com/users/atlantisbot/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/atlantisbot/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/atlantisbot/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/atlantisbot/subscriptions',
#      'organizations_url': 'https://api.github.com/users/atlantisbot/orgs',
#      'repos_url': 'https://api.github.com/users/atlantisbot/repos',
#      'events_url': 'https://api.github.com/users/atlantisbot/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/atlantisbot/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': '',
#     'created_at': '2020-07-07T17:39:52Z',
#     'updated_at': '2020-07-07T17:39:52Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/runatlantis/atlantis-tests/pulls/1751/commits',
#     'review_comments_url': 'https://api.github.com/repos/runatlantis/atlantis-tests/pulls/1751/comments',
#     'review_comment_url': 'https://api.github.com/repos/runatlantis/atlantis-tests/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/runatlantis/atlantis-tests/issues/1751/comments',
#     'statuses_url': 'https://api.github.com/repos/runatlantis/atlantis-tests/statuses/ebe94aa1d3d7a79dbe3269814d138e4c20ff9a1b',
#     'head': {'label': 'runatlantis:standalone-20200707173948',
#      'ref': 'standalone-20200707173948',
#      'sha': 'ebe94aa1d3d7a79dbe3269814d138e4c20ff9a1b',
#      'user': {'login': 'runatlantis',
#       'id': 32311288,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjMyMzExMjg4',
#       'avatar_url': 'https://avatars2.githubusercontent.com/u/32311288?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/runatlantis',
#       'html_url': 'https://github.com/runatlantis',
#       'followers_url': 'https://api.github.com/users/runatlantis/followers',
#       'following_url': 'https://api.github.com/users/runatlantis/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/runatlantis/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/runatlantis/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/runatlantis/subscriptions',
#       'organizations_url': 'https://api.github.com/users/runatlantis/orgs',
#       'repos_url': 'https://api.github.com/users/runatlantis/repos',
#       'events_url': 'https://api.github.com/users/runatlantis/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/runatlantis/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 120520862,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxMjA1MjA4NjI=',
#       'name': 'atlantis-tests',
#       'full_name': 'runatlantis/atlantis-tests',
#       'private': False,
#       'owner': {'login': 'runatlantis',
#        'id': 32311288,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjMyMzExMjg4',
#        'avatar_url': 'https://avatars2.githubusercontent.com/u/32311288?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/runatlantis',
#        'html_url': 'https://github.com/runatlantis',
#        'followers_url': 'https://api.github.com/users/runatlantis/followers',
#        'following_url': 'https://api.github.com/users/runatlantis/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/runatlantis/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/runatlantis/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/runatlantis/subscriptions',
#        'organizations_url': 'https://api.github.com/users/runatlantis/orgs',
#        'repos_url': 'https://api.github.com/users/runatlantis/repos',
#        'events_url': 'https://api.github.com/users/runatlantis/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/runatlantis/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/runatlantis/atlantis-tests',
#       'description': 'A set of terraform projects that atlantis e2e tests run on.',
#       'fork': True,
#       'url': 'https://api.github.com/repos/runatlantis/atlantis-tests',
#       'forks_url': 'https://api.github.com/repos/runatlantis/atlantis-tests/forks',
#       'keys_url': 'https://api.github.com/repos/runatlantis/atlantis-tests/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/runatlantis/atlantis-tests/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/runatlantis/atlantis-tests/teams',
#       'hooks_url': 'https://api.github.com/repos/runatlantis/atlantis-tests/hooks',
#       'issue_events_url': 'https://api.github.com/repos/runatlantis/atlantis-tests/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/runatlantis/atlantis-tests/events',
#       'assignees_url': 'https://api.github.com/repos/runatlantis/atlantis-tests/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/runatlantis/atlantis-tests/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/runatlantis/atlantis-tests/tags',
#       'blobs_url': 'https://api.github.com/repos/runatlantis/atlantis-tests/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/runatlantis/atlantis-tests/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/runatlantis/atlantis-tests/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/runatlantis/atlantis-tests/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/runatlantis/atlantis-tests/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/runatlantis/atlantis-tests/languages',
#       'stargazers_url': 'https://api.github.com/repos/runatlantis/atlantis-tests/stargazers',
#       'contributors_url': 'https://api.github.com/repos/runatlantis/atlantis-tests/contributors',
#       'subscribers_url': 'https://api.github.com/repos/runatlantis/atlantis-tests/subscribers',
#       'subscription_url': 'https://api.github.com/repos/runatlantis/atlantis-tests/subscription',
#       'commits_url': 'https://api.github.com/repos/runatlantis/atlantis-tests/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/runatlantis/atlantis-tests/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/runatlantis/atlantis-tests/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/runatlantis/atlantis-tests/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/runatlantis/atlantis-tests/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/runatlantis/atlantis-tests/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/runatlantis/atlantis-tests/merges',
#       'archive_url': 'https://api.github.com/repos/runatlantis/atlantis-tests/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/runatlantis/atlantis-tests/downloads',
#       'issues_url': 'https://api.github.com/repos/runatlantis/atlantis-tests/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/runatlantis/atlantis-tests/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/runatlantis/atlantis-tests/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/runatlantis/atlantis-tests/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/runatlantis/atlantis-tests/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/runatlantis/atlantis-tests/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/runatlantis/atlantis-tests/deployments',
#       'created_at': '2018-02-06T20:42:50Z',
#       'updated_at': '2019-04-08T14:24:13Z',
#       'pushed_at': '2020-07-07T17:39:52Z',
#       'git_url': 'git://github.com/runatlantis/atlantis-tests.git',
#       'ssh_url': 'git@github.com:runatlantis/atlantis-tests.git',
#       'clone_url': 'https://github.com/runatlantis/atlantis-tests.git',
#       'svn_url': 'https://github.com/runatlantis/atlantis-tests',
#       'homepage': None,
#       'size': 5,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'HCL',
#       'has_issues': True,
#       'has_projects': False,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'forks_count': 1,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 2,
#       'license': {'key': 'other',
#        'name': 'Other',
#        'spdx_id': 'NOASSERTION',
#        'url': None,
#        'node_id': 'MDc6TGljZW5zZTA='},
#       'forks': 1,
#       'open_issues': 2,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'runatlantis:master',
#      'ref': 'master',
#      'sha': '717c9198920c3957592005678e30d6d1e42b0047',
#      'user': {'login': 'runatlantis',
#       'id': 32311288,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjMyMzExMjg4',
#       'avatar_url': 'https://avatars2.githubusercontent.com/u/32311288?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/runatlantis',
#       'html_url': 'https://github.com/runatlantis',
#       'followers_url': 'https://api.github.com/users/runatlantis/followers',
#       'following_url': 'https://api.github.com/users/runatlantis/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/runatlantis/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/runatlantis/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/runatlantis/subscriptions',
#       'organizations_url': 'https://api.github.com/users/runatlantis/orgs',
#       'repos_url': 'https://api.github.com/users/runatlantis/repos',
#       'events_url': 'https://api.github.com/users/runatlantis/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/runatlantis/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 120520862,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxMjA1MjA4NjI=',
#       'name': 'atlantis-tests',
#       'full_name': 'runatlantis/atlantis-tests',
#       'private': False,
#       'owner': {'login': 'runatlantis',
#        'id': 32311288,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjMyMzExMjg4',
#        'avatar_url': 'https://avatars2.githubusercontent.com/u/32311288?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/runatlantis',
#        'html_url': 'https://github.com/runatlantis',
#        'followers_url': 'https://api.github.com/users/runatlantis/followers',
#        'following_url': 'https://api.github.com/users/runatlantis/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/runatlantis/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/runatlantis/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/runatlantis/subscriptions',
#        'organizations_url': 'https://api.github.com/users/runatlantis/orgs',
#        'repos_url': 'https://api.github.com/users/runatlantis/repos',
#        'events_url': 'https://api.github.com/users/runatlantis/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/runatlantis/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/runatlantis/atlantis-tests',
#       'description': 'A set of terraform projects that atlantis e2e tests run on.',
#       'fork': True,
#       'url': 'https://api.github.com/repos/runatlantis/atlantis-tests',
#       'forks_url': 'https://api.github.com/repos/runatlantis/atlantis-tests/forks',
#       'keys_url': 'https://api.github.com/repos/runatlantis/atlantis-tests/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/runatlantis/atlantis-tests/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/runatlantis/atlantis-tests/teams',
#       'hooks_url': 'https://api.github.com/repos/runatlantis/atlantis-tests/hooks',
#       'issue_events_url': 'https://api.github.com/repos/runatlantis/atlantis-tests/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/runatlantis/atlantis-tests/events',
#       'assignees_url': 'https://api.github.com/repos/runatlantis/atlantis-tests/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/runatlantis/atlantis-tests/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/runatlantis/atlantis-tests/tags',
#       'blobs_url': 'https://api.github.com/repos/runatlantis/atlantis-tests/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/runatlantis/atlantis-tests/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/runatlantis/atlantis-tests/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/runatlantis/atlantis-tests/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/runatlantis/atlantis-tests/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/runatlantis/atlantis-tests/languages',
#       'stargazers_url': 'https://api.github.com/repos/runatlantis/atlantis-tests/stargazers',
#       'contributors_url': 'https://api.github.com/repos/runatlantis/atlantis-tests/contributors',
#       'subscribers_url': 'https://api.github.com/repos/runatlantis/atlantis-tests/subscribers',
#       'subscription_url': 'https://api.github.com/repos/runatlantis/atlantis-tests/subscription',
#       'commits_url': 'https://api.github.com/repos/runatlantis/atlantis-tests/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/runatlantis/atlantis-tests/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/runatlantis/atlantis-tests/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/runatlantis/atlantis-tests/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/runatlantis/atlantis-tests/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/runatlantis/atlantis-tests/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/runatlantis/atlantis-tests/merges',
#       'archive_url': 'https://api.github.com/repos/runatlantis/atlantis-tests/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/runatlantis/atlantis-tests/downloads',
#       'issues_url': 'https://api.github.com/repos/runatlantis/atlantis-tests/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/runatlantis/atlantis-tests/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/runatlantis/atlantis-tests/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/runatlantis/atlantis-tests/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/runatlantis/atlantis-tests/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/runatlantis/atlantis-tests/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/runatlantis/atlantis-tests/deployments',
#       'created_at': '2018-02-06T20:42:50Z',
#       'updated_at': '2019-04-08T14:24:13Z',
#       'pushed_at': '2020-07-07T17:39:52Z',
#       'git_url': 'git://github.com/runatlantis/atlantis-tests.git',
#       'ssh_url': 'git@github.com:runatlantis/atlantis-tests.git',
#       'clone_url': 'https://github.com/runatlantis/atlantis-tests.git',
#       'svn_url': 'https://github.com/runatlantis/atlantis-tests',
#       'homepage': None,
#       'size': 5,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'HCL',
#       'has_issues': True,
#       'has_projects': False,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'forks_count': 1,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 2,
#       'license': {'key': 'other',
#        'name': 'Other',
#        'spdx_id': 'NOASSERTION',
#        'url': None,
#        'node_id': 'MDc6TGljZW5zZTA='},
#       'forks': 1,
#       'open_issues': 2,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/runatlantis/atlantis-tests/pulls/1751'},
#      'html': {'href': 'https://github.com/runatlantis/atlantis-tests/pull/1751'},
#      'issue': {'href': 'https://api.github.com/repos/runatlantis/atlantis-tests/issues/1751'},
#      'comments': {'href': 'https://api.github.com/repos/runatlantis/atlantis-tests/issues/1751/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/runatlantis/atlantis-tests/pulls/1751/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/runatlantis/atlantis-tests/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/runatlantis/atlantis-tests/pulls/1751/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/runatlantis/atlantis-tests/statuses/ebe94aa1d3d7a79dbe3269814d138e4c20ff9a1b'}},
#     'author_association': 'COLLABORATOR',
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 3,
#     'deletions': 0,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2020-07-07T17:39:53Z',
#   'org': {'id': 32311288,
#    'login': 'runatlantis',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/runatlantis',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/32311288?'}},
#  {'id': '12838545950',
#   'type': 'CreateEvent',
#   'actor': {'id': 42633,
#    'login': 'espindola',
#    'display_login': 'espindola',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/espindola',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/42633?'},
#   'repo': {'id': 160407387,
#    'name': 'espindola/seastar',
#    'url': 'https://api.github.com/repos/espindola/seastar'},
#   'payload': {'ref': 'espindola/fix-std-bad-alloc-v2',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'High performance server-side application framework',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-07-07T17:39:53Z'},
#  {'id': '12838545931',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 266368284,
#    'name': 'tissueMO/vuejs-tutorial',
#    'url': 'https://api.github.com/repos/tissueMO/vuejs-tutorial'},
#   'payload': {'push_id': 5339241217,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/gh-pages',
#    'head': '214eba5418d87bff1e09071c5d5f09234a3f47ab',
#    'before': 'e383a6cc67dd55443d87b997ba25cfc0d65868bf',
#    'commits': [{'sha': '214eba5418d87bff1e09071c5d5f09234a3f47ab',
#      'author': {'email': 'tissueMO@users.noreply.github.com',
#       'name': 'tissueMO'},
#      'message': 'deploy: 9d2c4878d2dc363d9aacea8c82b98f2a38cf1c18',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/tissueMO/vuejs-tutorial/commits/214eba5418d87bff1e09071c5d5f09234a3f47ab'}]},
#   'public': True,
#   'created_at': '2020-07-07T17:39:53Z'},
#  {'id': '12838545930',
#   'type': 'PushEvent',
#   'actor': {'id': 54211182,
#    'login': 'RupakVeerla',
#    'display_login': 'RupakVeerla',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/RupakVeerla',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/54211182?'},
#   'repo': {'id': 277872626,
#    'name': 'RupakVeerla/start-here-guidelines',
#    'url': 'https://api.github.com/repos/RupakVeerla/start-here-guidelines'},
#   'payload': {'push_id': 5339241231,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '2d8a79a2ea13504714e5511288c690fa1903cdf9',
#    'before': '6951b1b4e6cc990cd31ffb0d636dee635d813c87',
#    'commits': [{'sha': '2d8a79a2ea13504714e5511288c690fa1903cdf9',
#      'author': {'email': 'Rupaksai@gmail.com', 'name': 'Rupak'},
#      'message': 'Added My name in Contributors',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/RupakVeerla/start-here-guidelines/commits/2d8a79a2ea13504714e5511288c690fa1903cdf9'}]},
#   'public': True,
#   'created_at': '2020-07-07T17:39:53Z'},
#  {'id': '12838545933',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 917931,
#    'login': 'BenTheElder',
#    'display_login': 'BenTheElder',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/BenTheElder',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/917931?'},
#   'repo': {'id': 57333709,
#    'name': 'kubernetes/test-infra',
#    'url': 'https://api.github.com/repos/kubernetes/test-infra'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/kubernetes/test-infra/issues/18193',
#     'repository_url': 'https://api.github.com/repos/kubernetes/test-infra',
#     'labels_url': 'https://api.github.com/repos/kubernetes/test-infra/issues/18193/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/kubernetes/test-infra/issues/18193/comments',
#     'events_url': 'https://api.github.com/repos/kubernetes/test-infra/issues/18193/events',
#     'html_url': 'https://github.com/kubernetes/test-infra/pull/18193',
#     'id': 652447851,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0NDQ1NTEzOTAx',
#     'number': 18193,
#     'title': 'Port triage/berghelroach.py to Go',
#     'user': {'login': 'michaelkolber',
#      'id': 20274958,
#      'node_id': 'MDQ6VXNlcjIwMjc0OTU4',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/20274958?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/michaelkolber',
#      'html_url': 'https://github.com/michaelkolber',
#      'followers_url': 'https://api.github.com/users/michaelkolber/followers',
#      'following_url': 'https://api.github.com/users/michaelkolber/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/michaelkolber/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/michaelkolber/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/michaelkolber/subscriptions',
#      'organizations_url': 'https://api.github.com/users/michaelkolber/orgs',
#      'repos_url': 'https://api.github.com/users/michaelkolber/repos',
#      'events_url': 'https://api.github.com/users/michaelkolber/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/michaelkolber/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 446458475,
#       'node_id': 'MDU6TGFiZWw0NDY0NTg0NzU=',
#       'url': 'https://api.github.com/repos/kubernetes/test-infra/labels/area/triage',
#       'name': 'area/triage',
#       'color': '0052cc',
#       'default': False,
#       'description': None},
#      {'id': 484580953,
#       'node_id': 'MDU6TGFiZWw0ODQ1ODA5NTM=',
#       'url': 'https://api.github.com/repos/kubernetes/test-infra/labels/cncf-cla:%20yes',
#       'name': 'cncf-cla: yes',
#       'color': 'bfe5bf',
#       'default': False,
#       'description': "Indicates the PR's author has signed the CNCF CLA."},
#      {'id': 582641099,
#       'node_id': 'MDU6TGFiZWw1ODI2NDEwOTk=',
#       'url': 'https://api.github.com/repos/kubernetes/test-infra/labels/needs-ok-to-test',
#       'name': 'needs-ok-to-test',
#       'color': 'b60205',
#       'default': False,
#       'description': 'Indicates a PR that requires an org member to verify it is safe to test.'},
#      {'id': 718255721,
#       'node_id': 'MDU6TGFiZWw3MTgyNTU3MjE=',
#       'url': 'https://api.github.com/repos/kubernetes/test-infra/labels/sig/testing',
#       'name': 'sig/testing',
#       'color': 'd2b48c',
#       'default': False,
#       'description': 'Categorizes an issue or PR as relevant to sig-testing.'},
#      {'id': 671133413,
#       'node_id': 'MDU6TGFiZWw2NzExMzM0MTM=',
#       'url': 'https://api.github.com/repos/kubernetes/test-infra/labels/size/XXL',
#       'name': 'size/XXL',
#       'color': 'ee0000',
#       'default': False,
#       'description': 'Denotes a PR that changes 1000+ lines, ignoring generated files.'}],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 5,
#     'created_at': '2020-07-07T16:12:04Z',
# ...
#        'avatar_url': 'https://avatars3.githubusercontent.com/u/78529?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/djberg96',
#        'html_url': 'https://github.com/djberg96',
#        'followers_url': 'https://api.github.com/users/djberg96/followers',
#        'following_url': 'https://api.github.com/users/djberg96/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/djberg96/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/djberg96/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/djberg96/subscriptions',
#        'organizations_url': 'https://api.github.com/users/djberg96/orgs',
#        'repos_url': 'https://api.github.com/users/djberg96/repos',
#        'events_url': 'https://api.github.com/users/djberg96/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/djberg96/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/djberg96/vmware_web_service',
#       'description': 'A ruby interface to Vmware Web Services SDK',
#       'fork': True,
#       'url': 'https://api.github.com/repos/djberg96/vmware_web_service',
#       'forks_url': 'https://api.github.com/repos/djberg96/vmware_web_service/forks',
#       'keys_url': 'https://api.github.com/repos/djberg96/vmware_web_service/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/djberg96/vmware_web_service/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/djberg96/vmware_web_service/teams',
#       'hooks_url': 'https://api.github.com/repos/djberg96/vmware_web_service/hooks',
#       'issue_events_url': 'https://api.github.com/repos/djberg96/vmware_web_service/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/djberg96/vmware_web_service/events',
#       'assignees_url': 'https://api.github.com/repos/djberg96/vmware_web_service/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/djberg96/vmware_web_service/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/djberg96/vmware_web_service/tags',
#       'blobs_url': 'https://api.github.com/repos/djberg96/vmware_web_service/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/djberg96/vmware_web_service/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/djberg96/vmware_web_service/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/djberg96/vmware_web_service/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/djberg96/vmware_web_service/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/djberg96/vmware_web_service/languages',
#       'stargazers_url': 'https://api.github.com/repos/djberg96/vmware_web_service/stargazers',
#       'contributors_url': 'https://api.github.com/repos/djberg96/vmware_web_service/contributors',
#       'subscribers_url': 'https://api.github.com/repos/djberg96/vmware_web_service/subscribers',
#       'subscription_url': 'https://api.github.com/repos/djberg96/vmware_web_service/subscription',
#       'commits_url': 'https://api.github.com/repos/djberg96/vmware_web_service/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/djberg96/vmware_web_service/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/djberg96/vmware_web_service/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/djberg96/vmware_web_service/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/djberg96/vmware_web_service/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/djberg96/vmware_web_service/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/djberg96/vmware_web_service/merges',
#       'archive_url': 'https://api.github.com/repos/djberg96/vmware_web_service/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/djberg96/vmware_web_service/downloads',
#       'issues_url': 'https://api.github.com/repos/djberg96/vmware_web_service/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/djberg96/vmware_web_service/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/djberg96/vmware_web_service/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/djberg96/vmware_web_service/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/djberg96/vmware_web_service/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/djberg96/vmware_web_service/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/djberg96/vmware_web_service/deployments',
#       'created_at': '2019-01-09T19:13:29Z',
#       'updated_at': '2020-07-07T16:58:58Z',
#       'pushed_at': '2020-07-07T17:33:35Z',
#       'git_url': 'git://github.com/djberg96/vmware_web_service.git',
#       'ssh_url': 'git@github.com:djberg96/vmware_web_service.git',
#       'clone_url': 'https://github.com/djberg96/vmware_web_service.git',
#       'svn_url': 'https://github.com/djberg96/vmware_web_service',
#       'homepage': None,
#       'size': 1189,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Ruby',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': {'key': 'apache-2.0',
#        'name': 'Apache License 2.0',
#        'spdx_id': 'Apache-2.0',
#        'url': 'https://api.github.com/licenses/apache-2.0',
#        'node_id': 'MDc6TGljZW5zZTI='},
#       'forks': 0,
#       'open_issues': 0,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'ManageIQ:master',
#      'ref': 'master',
#      'sha': '91fdf7a1a791964bb8414f0b270625b2b1b9902d',
#      'user': {'login': 'ManageIQ',
#       'id': 1125575,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjExMjU1NzU=',
#       'avatar_url': 'https://avatars0.githubusercontent.com/u/1125575?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/ManageIQ',
#       'html_url': 'https://github.com/ManageIQ',
#       'followers_url': 'https://api.github.com/users/ManageIQ/followers',
#       'following_url': 'https://api.github.com/users/ManageIQ/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/ManageIQ/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/ManageIQ/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/ManageIQ/subscriptions',
#       'organizations_url': 'https://api.github.com/users/ManageIQ/orgs',
#       'repos_url': 'https://api.github.com/users/ManageIQ/repos',
#       'events_url': 'https://api.github.com/users/ManageIQ/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/ManageIQ/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 92329104,
#       'node_id': 'MDEwOlJlcG9zaXRvcnk5MjMyOTEwNA==',
#       'name': 'vmware_web_service',
#       'full_name': 'ManageIQ/vmware_web_service',
#       'private': False,
#       'owner': {'login': 'ManageIQ',
#        'id': 1125575,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjExMjU1NzU=',
#        'avatar_url': 'https://avatars0.githubusercontent.com/u/1125575?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/ManageIQ',
#        'html_url': 'https://github.com/ManageIQ',
#        'followers_url': 'https://api.github.com/users/ManageIQ/followers',
#        'following_url': 'https://api.github.com/users/ManageIQ/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/ManageIQ/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/ManageIQ/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/ManageIQ/subscriptions',
#        'organizations_url': 'https://api.github.com/users/ManageIQ/orgs',
#        'repos_url': 'https://api.github.com/users/ManageIQ/repos',
#        'events_url': 'https://api.github.com/users/ManageIQ/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/ManageIQ/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/ManageIQ/vmware_web_service',
#       'description': 'A ruby interface to Vmware Web Services SDK',
#       'fork': False,
#       'url': 'https://api.github.com/repos/ManageIQ/vmware_web_service',
#       'forks_url': 'https://api.github.com/repos/ManageIQ/vmware_web_service/forks',
#       'keys_url': 'https://api.github.com/repos/ManageIQ/vmware_web_service/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/ManageIQ/vmware_web_service/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/ManageIQ/vmware_web_service/teams',
#       'hooks_url': 'https://api.github.com/repos/ManageIQ/vmware_web_service/hooks',
#       'issue_events_url': 'https://api.github.com/repos/ManageIQ/vmware_web_service/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/ManageIQ/vmware_web_service/events',
#       'assignees_url': 'https://api.github.com/repos/ManageIQ/vmware_web_service/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/ManageIQ/vmware_web_service/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/ManageIQ/vmware_web_service/tags',
#       'blobs_url': 'https://api.github.com/repos/ManageIQ/vmware_web_service/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/ManageIQ/vmware_web_service/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/ManageIQ/vmware_web_service/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/ManageIQ/vmware_web_service/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/ManageIQ/vmware_web_service/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/ManageIQ/vmware_web_service/languages',
#       'stargazers_url': 'https://api.github.com/repos/ManageIQ/vmware_web_service/stargazers',
#       'contributors_url': 'https://api.github.com/repos/ManageIQ/vmware_web_service/contributors',
#       'subscribers_url': 'https://api.github.com/repos/ManageIQ/vmware_web_service/subscribers',
#       'subscription_url': 'https://api.github.com/repos/ManageIQ/vmware_web_service/subscription',
#       'commits_url': 'https://api.github.com/repos/ManageIQ/vmware_web_service/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/ManageIQ/vmware_web_service/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/ManageIQ/vmware_web_service/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/ManageIQ/vmware_web_service/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/ManageIQ/vmware_web_service/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/ManageIQ/vmware_web_service/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/ManageIQ/vmware_web_service/merges',
#       'archive_url': 'https://api.github.com/repos/ManageIQ/vmware_web_service/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/ManageIQ/vmware_web_service/downloads',
#       'issues_url': 'https://api.github.com/repos/ManageIQ/vmware_web_service/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/ManageIQ/vmware_web_service/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/ManageIQ/vmware_web_service/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/ManageIQ/vmware_web_service/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/ManageIQ/vmware_web_service/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/ManageIQ/vmware_web_service/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/ManageIQ/vmware_web_service/deployments',
#       'created_at': '2017-05-24T19:31:48Z',
#       'updated_at': '2020-06-23T17:01:11Z',
#       'pushed_at': '2020-07-07T17:37:35Z',
#       'git_url': 'git://github.com/ManageIQ/vmware_web_service.git',
#       'ssh_url': 'git@github.com:ManageIQ/vmware_web_service.git',
#       'clone_url': 'https://github.com/ManageIQ/vmware_web_service.git',
#       'svn_url': 'https://github.com/ManageIQ/vmware_web_service',
#       'homepage': None,
#       'size': 1350,
#       'stargazers_count': 6,
#       'watchers_count': 6,
#       'language': 'Ruby',
#       'has_issues': True,
#       'has_projects': False,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'forks_count': 24,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 3,
#       'license': {'key': 'apache-2.0',
#        'name': 'Apache License 2.0',
#        'spdx_id': 'Apache-2.0',
#        'url': 'https://api.github.com/licenses/apache-2.0',
#        'node_id': 'MDc6TGljZW5zZTI='},
#       'forks': 24,
#       'open_issues': 3,
#       'watchers': 6,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/ManageIQ/vmware_web_service/pulls/81'},
#      'html': {'href': 'https://github.com/ManageIQ/vmware_web_service/pull/81'},
#      'issue': {'href': 'https://api.github.com/repos/ManageIQ/vmware_web_service/issues/81'},
#      'comments': {'href': 'https://api.github.com/repos/ManageIQ/vmware_web_service/issues/81/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/ManageIQ/vmware_web_service/pulls/81/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/ManageIQ/vmware_web_service/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/ManageIQ/vmware_web_service/pulls/81/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/ManageIQ/vmware_web_service/statuses/104ebb2e60250058e4b2d50898dfd7331b22bf79'}},
#     'author_association': 'NONE',
#     'active_lock_reason': None}},
#   'public': True,
#   'created_at': '2020-07-07T17:39:52Z',
#   'org': {'id': 1125575,
#    'login': 'ManageIQ',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/ManageIQ',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1125575?'}},
#  {'id': '12838545877',
#   'type': 'MemberEvent',
#   'actor': {'id': 33384952,
#    'login': 'HimOnly',
#    'display_login': 'HimOnly',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/HimOnly',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/33384952?'},
#   'repo': {'id': 276639265,
#    'name': 'HimOnly/D3-BOOTCAMP-final-project-git-basics-course',
#    'url': 'https://api.github.com/repos/HimOnly/D3-BOOTCAMP-final-project-git-basics-course'},
#   'payload': {'member': {'login': 'BrightAdeGodson',
#     'id': 64380141,
#     'node_id': 'MDQ6VXNlcjY0MzgwMTQx',
#     'avatar_url': 'https://avatars3.githubusercontent.com/u/64380141?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/BrightAdeGodson',
#     'html_url': 'https://github.com/BrightAdeGodson',
#     'followers_url': 'https://api.github.com/users/BrightAdeGodson/followers',
#     'following_url': 'https://api.github.com/users/BrightAdeGodson/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/BrightAdeGodson/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/BrightAdeGodson/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/BrightAdeGodson/subscriptions',
#     'organizations_url': 'https://api.github.com/users/BrightAdeGodson/orgs',
#     'repos_url': 'https://api.github.com/users/BrightAdeGodson/repos',
#     'events_url': 'https://api.github.com/users/BrightAdeGodson/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/BrightAdeGodson/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'action': 'added'},
#   'public': True,
#   'created_at': '2020-07-07T17:39:52Z'}]

# %% [markdown]
# ## 其它用法

# %%
payload = {'key1': 'value1', 'key2': 'value2'}
r = requests.get("http://httpbin.org/get", params=payload)
json.loads(r.text)
# Out:
# {'args': {'key1': 'value1', 'key2': 'value2'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.22.0',
#   'X-Amzn-Trace-Id': 'Root=1-5f04b568-767c5ae4db42fe8f59387e44'},
#  'origin': '122.116.28.120',
#  'url': 'http://httpbin.org/get?key1=value1&key2=value2'}

# %%
r = requests.post('http://httpbin.org/post', data = {'key':'value'})
json.loads(r.text)
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'key': 'value'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '9',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.22.0',
#   'X-Amzn-Trace-Id': 'Root=1-5f04b56c-b1fa8004341e8cc00fe56a7d'},
#  'json': None,
#  'origin': '122.116.28.120',
#  'url': 'http://httpbin.org/post'}

# %%
r = requests.post('http://httpbin.org/post', data = {'key':'value'})
json.loads(r.text)
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'key': 'value'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '9',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.22.0',
#   'X-Amzn-Trace-Id': 'Root=1-5f04b573-a06f1e0502085f0d002faff8'},
#  'json': None,
#  'origin': '122.116.28.120',
#  'url': 'http://httpbin.org/post'}

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)
